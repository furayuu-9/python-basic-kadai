# %% [markdown]
# <a href="https://colab.research.google.com/github/furayuu-9/python-basic-kadai/blob/main/kadai_013.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dai1 = 110
dai2 = 10

def tax(dai1, dai2):
  price = (dai1 + (dai1 * (dai2 / 100)))
  return price

price = tax(dai1, dai2)
print(price)
# Out:
# 121.0
